# %% [markdown]
# # R

# %%
x <- c(1,2,3,4,5)
y <- 1/x

# %%
x
# Out:
# [1] 1 2 3 4 5

# %%
y
# Out:
# [1] 1.0000000 0.5000000 0.3333333 0.2500000 0.2000000

# %%
plot(x,y)
# Out:
# plot without title
